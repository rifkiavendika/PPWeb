# %% [markdown]
# # Menggabungkan Dataset

# %%
import pandas as pd

# %% [markdown]
# # Dataset 1 Politik
# ---
# Dataset 1 kategori politik diambil pada berita online website Detik.com

# %%
politik = pd.read_csv('/content/drive/MyDrive/PPWeb/tugas/berita_detik.csv')
# Menambahkan kolom 'kategori' dengan nilai 'Politik'
politik = politik.assign(Kategori=['Politik'] * len(politik))
politik.head()
# Out:
#    Unnamed: 0                                       Judul Berita  \
# 0           0  Gibran Persilakan Bawaslu DKI Telusuri soal Ba...
# 1           1  Kunker ke NTT, Jokowi Cek Gudang Bulog hingga ...
# 2           2  DPRD DKI Minta Pemprov Segera Tuntaskan soal G...
# 3           3  Pakai Jersey Nomor 22, Jokowi Main Bola Bareng...
# 4           4  Massa 'Paman Usman' Geruduk Kantor PSI DIY Bun...
#
#                                           Isi Berita Kategori
# 0  Jakarta - Cawapres nomor urut 2, Gibran Rakabu...  Politik
# 1  Jakarta - Presiden Joko Widodo (Jokowi) melaku...  Politik
# 2  Jakarta - Komisi A DPRD DKI Jakarta meminta Pe...  Politik
# 3  Manggarai Barat - Presiden Joko Widodo (Jokowi...  Politik
# 4  Puluhan massa yang mengatasnamakan diri Paguyu...  Politik

# %% [markdown]
# # Dataset 2 Olahraga
# ---
# Dataset 2 kategori olahraga diambil pada berita online website Detik.com

# %%
olahraga = pd.read_csv('/content/drive/MyDrive/PPWeb/tugas/berita_detik2.csv')
# Menambahkan kolom 'kategori' dengan nilai 'olahraga'
olahraga = olahraga.assign(Kategori=['Olahraga'] * len(olahraga))
olahraga.head()
# Out:
#    Unnamed: 0                                       Judul Berita  \
# 0           0  Foto: Aksi Ciamik Para Pebulutangkis Muda BNI ...
# 1           1  Atlet Para Cycling RI Raih 3 Emas di World Abi...
# 2           2  Dzaky Kalahkan Khadafi, Maju ke 64 Besar BNI S...
# 3           3  Demi Medali Olimpiade, Gregoria Bertekad Lebih...
# 4           4  Gregoria Waspadai Faktor Nonteknis di BWF Worl...
#
#                                           Isi Berita  Kategori
# 0  Pekanbaru - Ajang bulutangkis BNI Sirkuit Nasi...  Olahraga
# 1  Jakarta - Tiga atlet para-cycling Indonesia me...  Olahraga
# 2  Pekanbaru - Ajang untuk pebulutangkis muda BNI...  Olahraga
# 3  Jakarta - Gregoria Mariska Tunjung menjadi sal...  Olahraga
# 4  Jakarta - Pebulutangkis putri Gregoria Mariska...  Olahraga

# %% [markdown]
# # Dataset 3 Politik
# ---
# Dataset 3 kategori Kesehatan diambil pada berita online website Detik.com

# %%
kesehatan = pd.read_csv('/content/drive/MyDrive/PPWeb/tugas/berita_detik3.csv')
# Menambahkan kolom 'kategori' dengan nilai 'kesehatan'
kesehatan = kesehatan.assign(Kategori=['Kesehatan'] * len(kesehatan))
kesehatan.head()
# Out:
#    Unnamed: 0                                       Judul Berita  \
# 0           0  Cerita Petugas RS China soal Lonjakan Pneumoni...
# 1           1  Pemerintah Malaysia Minta Warganya Nikah Muda ...
# 2           2  Rajin Minum Susu Jadi Penangkal Kanker Paru? T...
# 3           3  Disebut Picu Lonjakan Kasus COVID di Singapura...
# 4           4  316 Warga Gaza Tewas Pasca Gencatan Senjata Be...
#
#                                           Isi Berita   Kategori
# 0  Jakarta - Penyakit pernapasan pneumonia tengah...  Kesehatan
# 1  Jakarta - Kementerian Perempuan, Keluarga, dan...  Kesehatan
# 2  Jakarta - Kanker paru merupakan salah satu jen...  Kesehatan
# 3  Daftar Isi\n\n\n\n\r\n\t\t\t\t\t\t\tGejala Omi...  Kesehatan
# 4  Jakarta - Rumah Sakit Nasser di Gaza bagian se...  Kesehatan

# %% [markdown]
# # Menggabungkan Dataset

# %%
# Menggabungkan ketiga DataFrame menjadi satu DataFrame
combined_df = pd.concat([politik, olahraga, kesehatan], axis=0)

# Mengacak baris-baris dari DataFrame yang telah digabungkan
all_kategori = combined_df.sample(frac=1).reset_index(drop=True)
all_kategori = all_kategori.drop('Unnamed: 0', axis=1)

# %%
# Simpan DataFrame yang telah digabung dan diacak ke dalam file CSV
all_kategori.to_csv('/content/drive/MyDrive/PPWeb/tugas/all_kategori.csv', index=False)

# %%
df = all_kategori
df
# Out:
#                                           Judul Berita  \
# 0    'Biang Kerok' Lonjakan Kasus COVID-19 Singapur...
# 1    Militer Filipina Buru Pelaku Ledakan Bom Saat ...
# 2    Apa Itu Sindrom Tourette? Ini Gejala dan Penye...
# 3    Jonatan Christie Menikah Pekan Ini, Latihan di...
# 4    113 Klub Bulutangkis Nasional Ramaikan BNI Sir...
# ..                                                 ...
# 295  Kulit di Bagian Selangkangan Terasa Kering dan...
# 296         5 Berita Terpopuler Internasional Hari Ini
# 297                Daftar Lengkap 22 Rider MotoGP 2024
# 298  Menyusuri Kampung Segeram yang Dihuni Penduduk...
# 299  Pasien 'Cacar Monyet' Mpox di RI Kini Tembus 6...
#
#                                             Isi Berita   Kategori
# 0    Jakarta - Kementerian Kesehatan Singapura mela...  Kesehatan
# 1    Manila -  Perburuan besar-besaran sedang dilak...    Politik
# 2    Daftar Isi\n\n\n\n\r\n\t\t\t\t\t\t\tPengertian...  Kesehatan
# ...

# %% [markdown]
# # Search RankBerita

# %% [markdown]
# # Instalasi

# %%
import pandas as pd
import nltk
import re
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

# %%
nltk.download('punkt')
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Data
#
# Data yang digunakan menggunakan hasil crawling data pada website Detik.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/PPWeb/tugas/all_kategori.csv')
df
# Out:
#                                           Judul Berita  \
# 0    Mahfud Gelar Rapat Bahas Polemik Penolakan Pen...
# 1    Apresiasi WHO Atas Kehadiran Hari Kesehatan Pe...
# 2    Foto: Aksi Ciamik Para Pebulutangkis Muda BNI ...
# 3    Potret Perjalanan Kiki Fatmala Lawan Kanker Pa...
# 4    KuTips: Simak Cara Buang Obat di Rumah yang Te...
# ..                                                 ...
# 295  Kejurnas IMI Adventure Off-road Putaran Kedua ...
# 296          MotoGP Valencia 2023 Positif untuk Diggia
# 297  Dinkes DKI Laporkan Sejumlah Anak Kena Mycopla...
# 298  Menkes soal RI Jadi Negara Maju: Masyarakatnya...
# 299  Mengenal Apa Itu Mioma Uteri: Penyebab, Gejala...
#
#                                             Isi Berita   Kategori
# 0    Jakarta - Menko Polhukam Mahfud Md akan mengge...    Politik
# 1    Jakarta - Dirjen WHO, Dr Tedros Adhanom Ghebre...  Kesehatan
# 2    Pekanbaru - Ajang bulutangkis BNI Sirkuit Nasi...   Olahraga
# ...

# %%
berita = df['Isi Berita'].iloc[4]
berita
# Out:
# 'Detikers, obat yang kita konsumsi di rumah apabila sudah kadaluwarsa atau rusak harus dibuang ya, tapi buangnya jangan sembarangan untuk menghindari obat digunakan kembali oleh oknum tak bertanggung jawab dan agar tidak mencemari lingkungan. Emangnya gimana sih cara buang yang tepat? Yuk simak caranya di episode KuTips berikut!'

# %% [markdown]
# # Preprocessing

# %%
def preprocessing(text):
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s.]', '', text)
    text = text.lower()

    stop_words = set(stopwords.words('indonesian'))
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]

    preprocessing_text = ' '.join(filtered_words)

    return preprocessing_text

# %%
berita = preprocessing(berita)
print(berita)
# Out:
# detikers obat konsumsi rumah kadaluwarsa rusak dibuang ya buangnya sembarangan menghindari obat oknum bertanggung mencemari lingkungan. emangnya gimana sih buang yuk simak episode kutips

# %% [markdown]
# # Membentuk Matriks

# %% [markdown]
# ## Memisahkan Kalimat

# %%
kalimat = nltk.sent_tokenize(berita)
kalimat = [sentence.replace('.', '') for sentence in kalimat]
print(kalimat)
# Out:
# ['detikers obat konsumsi rumah kadaluwarsa rusak dibuang ya buangnya sembarangan menghindari obat oknum bertanggung mencemari lingkungan', 'emangnya gimana sih buang yuk simak episode kutips']

# %% [markdown]
# ## Memisahkan Kata

# %%
kata = word_tokenize(berita)
kata = [k.lower() for k in kata if k != '.']
kata = list(set(kata))
print(kata)
# Out:
# ['rumah', 'dibuang', 'gimana', 'lingkungan', 'simak', 'kutips', 'rusak', 'emangnya', 'sih', 'episode', 'buang', 'ya', 'sembarangan', 'menghindari', 'bertanggung', 'oknum', 'konsumsi', 'kadaluwarsa', 'mencemari', 'yuk', 'obat', 'buangnya', 'detikers']

# %% [markdown]
# ## Matriks Kata dalam Berita

# %%
matrikskata = pd.DataFrame(0, index=kata, columns=kata)

# %%
for sent in kalimat:
    kata_kalimat = word_tokenize(sent)
    for i in range(len(kata_kalimat)-1):
        matrikskata.at[kata_kalimat[i], kata_kalimat[i+1]] += 1 # jika kata pada sebelah kanan
        matrikskata.at[kata_kalimat[i+1], kata_kalimat[i]] += 1 # jika kata pada sebelah kiri

# %%
matrikskata
# Out:
#              rumah  dibuang  gimana  lingkungan  simak  kutips  rusak  \
# rumah            0        0       0           0      0       0      0
# dibuang          0        0       0           0      0       0      1
# gimana           0        0       0           0      0       0      0
# lingkungan       0        0       0           0      0       0      0
# simak            0        0       0           0      0       0      0
# kutips           0        0       0           0      0       0      0
# rusak            0        1       0           0      0       0      0
# emangnya         0        0       1           0      0       0      0
# sih              0        0       1           0      0       0      0
# episode          0        0       0           0      1       1      0
# buang            0        0       0           0      0       0      0
# ya               0        1       0           0      0       0      0
# ...

# %% [markdown]
# # Membentuk Graph

# %% [markdown]
# ## Cosine Similarity

# %%
cosine = cosine_similarity(matrikskata, matrikskata)

# %%
similarity = pd.DataFrame(cosine, columns=matrikskata.index, index=matrikskata.index)
similarity
# Out:
#                 rumah  dibuang  gimana  lingkungan     simak    kutips  rusak  \
# rumah        1.000000      0.0     0.0    0.000000  0.000000  0.000000    0.5
# dibuang      0.000000      1.0     0.0    0.000000  0.000000  0.000000    0.0
# gimana       0.000000      0.0     1.0    0.000000  0.000000  0.000000    0.0
# lingkungan   0.000000      0.0     0.0    1.000000  0.000000  0.000000    0.0
# simak        0.000000      0.0     0.0    0.000000  1.000000  0.707107    0.0
# kutips       0.000000      0.0     0.0    0.000000  0.707107  1.000000    0.0
# rusak        0.500000      0.0     0.0    0.000000  0.000000  0.000000    1.0
# emangnya     0.000000      0.0     0.0    0.000000  0.000000  0.000000    0.0
# sih          0.000000      0.0     0.0    0.000000  0.000000  0.000000    0.0
# episode      0.000000      0.0     0.0    0.000000  0.000000  0.000000    0.0
# buang        0.000000      0.0     0.5    0.000000  0.500000  0.000000    0.0
# ...

# %% [markdown]
# ## Graph

# %%
G = nx.DiGraph()
for i in range(len(cosine)):
    G.add_node(i)

for i in range(len(cosine)):
    for j in range(len(cosine)):
        similarity = cosine[i][j]
        if similarity > 0.1 and i != j:
            G.add_edge(i, j)

pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=500, node_color='b')
nx.draw_networkx_edges(G, pos, edge_color='red', arrows=True)
nx.draw_networkx_labels(G, pos)

plt.show()

# %% [markdown]
# # Hasil Kata Kunci

# %% [markdown]
# ## Page Rank

# %%
pagerank = nx.pagerank(G)

sorted_pagerank= sorted(pagerank.items(), key=lambda x: x[1], reverse=True)
print("Page Rank :")
for node, pagerank in sorted_pagerank:
    print(f"Node {node}: {pagerank:.4f}")
# Out:
# Page Rank :
# Node 20: 0.0621
# Node 15: 0.0609
# Node 13: 0.0593
# Node 16: 0.0593
# Node 4: 0.0564
# Node 8: 0.0564
# Node 10: 0.0564
# Node 19: 0.0564
# Node 14: 0.0465
# Node 22: 0.0447
# Node 6: 0.0425
# Node 11: 0.0425
# Node 0: 0.0422
# Node 12: 0.0422
# Node 1: 0.0357
# Node 17: 0.0343
# Node 21: 0.0343
# Node 2: 0.0305
# Node 5: 0.0305
# Node 7: 0.0305
# Node 9: 0.0305
# Node 3: 0.0263
# Node 18: 0.0195

# %%
print("Tiga Node Tertinggi Page Rank :")
sentence = ""
for node, pagerank in sorted_pagerank[:3]:
  top_sentence = kata[node]
  sentence += top_sentence + ", "
  print(f"Node {node}: Page Rank = {pagerank:.4f}")
  print(f"Kalimat: {top_sentence}")
# Out:
# Tiga Node Tertinggi Page Rank :
# Node 20: Page Rank = 0.0621
# Kalimat: obat
# Node 15: Page Rank = 0.0609
# Kalimat: oknum
# Node 13: Page Rank = 0.0593
# Kalimat: menghindari

# %% [markdown]
# ## Kata Kunci Berita

# %%
news = df['Isi Berita'].iloc[4]
print('Berita yang digunakan : ')
news
# Out:
# Berita yang digunakan :
# 'Detikers, obat yang kita konsumsi di rumah apabila sudah kadaluwarsa atau rusak harus dibuang ya, tapi buangnya jangan sembarangan untuk menghindari obat digunakan kembali oleh oknum tak bertanggung jawab dan agar tidak mencemari lingkungan. Emangnya gimana sih cara buang yang tepat? Yuk simak caranya di episode KuTips berikut!'

# %%
print('Kata Kunci :', sentence)
# Out:
# Kata Kunci : obat, oknum, menghindari,
